# %%
import ROOT
import numpy as np
import math
from ROOT import TMath
import math
from math import exp
import os
# %jsroot on
# Out:
# Welcome to JupyROOT 6.18/04

# %%
#make chains for data and MC

#data
data = ROOT.TChain("mini")
data.Add("/opendata/W->lv/Data-1lep/Data/data_A.1lep.root")
data.Add("/opendata/W->lv/Data-1lep/Data/data_B.1lep.root")
data.Add("/opendata/W->lv/Data-1lep/Data/data_C.1lep.root")
data.Add("/opendata/W->lv/Data-1lep/Data/data_D.1lep.root")
data.GetEntries()

# %%
#MC
Zee = ROOT.TChain("mini")
Zee.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_361106.Zee.1lep.root")


Zmumu = ROOT.TChain("mini")
Zmumu.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_361107.Zmumu.1lep.root")

Ztautau = ROOT.TChain("mini")
Ztautau.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_361108.Ztautau.1lep.root")

ZqqZll = ROOT.TChain("mini")
ZqqZll.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_363356.ZqqZll.1lep.root")

WqqZll = ROOT.TChain("mini")
WqqZll.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_363358.WqqZll.1lep.root")

WpqqWmlv = ROOT.TChain("mini")
WpqqWmlv.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_363359.WpqqWmlv.1lep.root")

WplvWmqq = ROOT.TChain("mini")
WplvWmqq.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_363360.WplvWmqq.1lep.root")

print(Zee.GetEntries())
print(Zmumu.GetEntries())
print(Ztautau.GetEntries())
print(ZqqZll.GetEntries())
print(WqqZll.GetEntries())
print(WpqqWmlv.GetEntries())
print(WplvWmqq.GetEntries())

# %%
WlvZqq = ROOT.TChain("mini")
WlvZqq.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_363489.WlvZqq.1lep.root")

llll = ROOT.TChain("mini")
llll.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_363490.llll.1lep.root")

lllv = ROOT.TChain("mini")
lllv.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_363491.lllv.1lep.root")

llvv = ROOT.TChain("mini")
llvv.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_363492.llvv.1lep.root")

lvvv = ROOT.TChain("mini")
lvvv.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_363493.lvvv.1lep.root")

ttbar_lep = ROOT.TChain("mini")
ttbar_lep.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_410000.ttbar_lep.1lep.root")

print(WlvZqq.GetEntries())
print(llll.GetEntries())
print(lllv.GetEntries())
print(llvv.GetEntries())
print(lvvv.GetEntries())
print(ttbar_lep.GetEntries())

# %%
single_top_tchan = ROOT.TChain("mini")
single_top_tchan.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_410011.single_top_tchan.1lep.root")

single_antitop_tchan = ROOT.TChain("mini")
single_antitop_tchan.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_410012.single_antitop_tchan.1lep.root")

single_top_wtchan = ROOT.TChain("mini")
single_top_wtchan.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_410013.single_top_wtchan.1lep.root")

single_antitop_wtchan = ROOT.TChain("mini")
single_antitop_wtchan.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_410014.single_antitop_wtchan.1lep.root")

single_top_schan = ROOT.TChain("mini")
single_top_schan.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_410025.single_top_schan.1lep.root")

single_antitop_schan = ROOT.TChain("mini")
single_antitop_schan.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_410026.single_antitop_schan.1lep.root")

print(single_top_tchan.GetEntries())
print(single_antitop_tchan.GetEntries())
print(single_top_wtchan.GetEntries())
print(single_antitop_wtchan.GetEntries())
print(single_top_schan.GetEntries())
print(single_antitop_schan.GetEntries())

# %%
Wmunu_PTV0_70_CVetoBVeto = ROOT.TChain("mini")
Wmunu_PTV0_70_CVetoBVeto.Add("/opendata/W->lv/MC-1-1lep/MC-1/mc_364156.Wmunu_PTV0_70_CVetoBVeto.1lep.root")
Wmunu_PTV0_70_CFilterBVeto = ROOT.TChain("mini")
Wmunu_PTV0_70_CFilterBVeto.Add("/opendata/W->lv/MC-1-1lep/MC-1/mc_364157.Wmunu_PTV0_70_CFilterBVeto.1lep.root")
Wmunu_PTV0_70_BFilter = ROOT.TChain("mini")
Wmunu_PTV0_70_BFilter.Add("/opendata/W->lv/MC-1-1lep/MC-1/mc_364158.Wmunu_PTV0_70_BFilter.1lep.root")
Wmunu_PTV70_140_CVetoBVeto = ROOT.TChain("mini")
Wmunu_PTV70_140_CVetoBVeto.Add("/opendata/W->lv/MC-1-1lep/MC-1/mc_364159.Wmunu_PTV70_140_CVetoBVeto.1lep.root")
Wmunu_PTV70_140_CFilterBVeto = ROOT.TChain("mini")
Wmunu_PTV70_140_CFilterBVeto.Add("/opendata/W->lv/MC-1-1lep/MC-1/mc_364160.Wmunu_PTV70_140_CFilterBVeto.1lep.root")
Wmunu_PTV70_140_BFilter = ROOT.TChain("mini")
Wmunu_PTV70_140_BFilter.Add("/opendata/W->lv/MC-1-1lep/MC-1/mc_364161.Wmunu_PTV70_140_BFilter.1lep.root")
Wmunu_PTV140_280_CVetoBVeto = ROOT.TChain("mini")
Wmunu_PTV140_280_CVetoBVeto.Add("/opendata/W->lv/MC-1-1lep/MC-1/mc_364162.Wmunu_PTV140_280_CVetoBVeto.1lep.root")
Wmunu_PTV140_280_CFilterBVeto = ROOT.TChain("mini")
Wmunu_PTV140_280_CFilterBVeto.Add("/opendata/W->lv/MC-1-1lep/MC-1/mc_364163.Wmunu_PTV140_280_CFilterBVeto.1lep.root")
Wmunu_PTV140_280_BFilter = ROOT.TChain("mini")
Wmunu_PTV140_280_BFilter.Add("/opendata/W->lv/MC-1-1lep/MC-1/mc_364164.Wmunu_PTV140_280_BFilter.1lep.root")
Wmunu_PTV280_500_CVetoBVeto = ROOT.TChain("mini")
Wmunu_PTV280_500_CVetoBVeto.Add("/opendata/W->lv/MC-1-1lep/MC-1/mc_364165.Wmunu_PTV280_500_CVetoBVeto.1lep.root")
Wmunu_PTV280_500_CFilterBVeto = ROOT.TChain("mini")
Wmunu_PTV280_500_CFilterBVeto.Add("/opendata/W->lv/MC-1-1lep/MC-1/mc_364166.Wmunu_PTV280_500_CFilterBVeto.1lep.root")
Wmunu_PTV280_500_BFilter = ROOT.TChain("mini")
Wmunu_PTV280_500_BFilter.Add("/opendata/W->lv/MC-1-1lep/MC-1/mc_364167.Wmunu_PTV280_500_BFilter.1lep.root")
Wmunu_PTV500_1000 = ROOT.TChain("mini")
Wmunu_PTV500_1000.Add("/opendata/W->lv/MC-1-1lep/MC-1/mc_364168.Wmunu_PTV500_1000.1lep.root")
Wmunu_PTV1000_E_CMS = ROOT.TChain("mini")
Wmunu_PTV1000_E_CMS.Add("/opendata/W->lv/MC-1-1lep/MC-1/mc_364169.Wmunu_PTV1000_E_CMS.1lep.root")

print(Wmunu_PTV0_70_CVetoBVeto.GetEntries())
print(Wmunu_PTV0_70_CFilterBVeto.GetEntries())
print(Wmunu_PTV0_70_BFilter.GetEntries())
print(Wmunu_PTV70_140_CVetoBVeto.GetEntries())
print(Wmunu_PTV70_140_CFilterBVeto.GetEntries())
print(Wmunu_PTV70_140_BFilter.GetEntries())
print(Wmunu_PTV140_280_CVetoBVeto.GetEntries())
print(Wmunu_PTV140_280_CFilterBVeto.GetEntries())
print(Wmunu_PTV140_280_BFilter.GetEntries())
print(Wmunu_PTV280_500_CVetoBVeto.GetEntries())
print(Wmunu_PTV280_500_CFilterBVeto.GetEntries())
print(Wmunu_PTV280_500_BFilter.GetEntries())
print(Wmunu_PTV500_1000.GetEntries())
print(Wmunu_PTV1000_E_CMS.GetEntries())

# %%
Wenu_PTV0_70_CVetoBVeto = ROOT.TChain("mini")
Wenu_PTV0_70_CVetoBVeto.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364170.Wenu_PTV0_70_CVetoBVeto.1lep.root")
Wenu_PTV0_70_CFilterBVeto = ROOT.TChain("mini")
Wenu_PTV0_70_CFilterBVeto.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364171.Wenu_PTV0_70_CFilterBVeto.1lep.root")
Wenu_PTV0_70_BFilter = ROOT.TChain("mini")
Wenu_PTV0_70_BFilter.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364172.Wenu_PTV0_70_BFilter.1lep.root")
Wenu_PTV70_140_CVetoBVeto = ROOT.TChain("mini")
Wenu_PTV70_140_CVetoBVeto.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364173.Wenu_PTV70_140_CVetoBVeto.1lep.root")
Wenu_PTV70_140_CFilterBVeto = ROOT.TChain("mini")
Wenu_PTV70_140_CFilterBVeto.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364174.Wenu_PTV70_140_CFilterBVeto.1lep.root")
Wenu_PTV70_140_BFilter = ROOT.TChain("mini")
Wenu_PTV70_140_BFilter.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364175.Wenu_PTV70_140_BFilter.1lep.root")
Wenu_PTV140_280_CVetoBVeto = ROOT.TChain("mini")
Wenu_PTV140_280_CVetoBVeto.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364176.Wenu_PTV140_280_CVetoBVeto.1lep.root")
Wenu_PTV140_280_CFilterBVeto = ROOT.TChain("mini")
Wenu_PTV140_280_CFilterBVeto.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364177.Wenu_PTV140_280_CFilterBVeto.1lep.root")
Wenu_PTV140_280_BFilter = ROOT.TChain("mini")
Wenu_PTV140_280_BFilter.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364178.Wenu_PTV140_280_BFilter.1lep.root")
Wenu_PTV280_500_CVetoBVeto = ROOT.TChain("mini")
Wenu_PTV280_500_CVetoBVeto.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364179.Wenu_PTV280_500_CVetoBVeto.1lep.root")
Wenu_PTV280_500_CFilterBVeto = ROOT.TChain("mini")
Wenu_PTV280_500_CFilterBVeto.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364180.Wenu_PTV280_500_CFilterBVeto.1lep.root")
Wenu_PTV280_500_BFilter = ROOT.TChain("mini")
Wenu_PTV280_500_BFilter.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364181.Wenu_PTV280_500_BFilter.1lep.root")
Wenu_PTV500_1000 = ROOT.TChain("mini")
Wenu_PTV500_1000.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364182.Wenu_PTV500_1000.1lep.root")
Wenu_PTV1000_E_CMS = ROOT.TChain("mini")
Wenu_PTV1000_E_CMS.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364183.Wenu_PTV1000_E_CMS.1lep.root")

print(Wenu_PTV0_70_CVetoBVeto.GetEntries())
print(Wenu_PTV0_70_CFilterBVeto.GetEntries())
print(Wenu_PTV0_70_BFilter.GetEntries())
print(Wenu_PTV70_140_CVetoBVeto.GetEntries())
print(Wenu_PTV70_140_CFilterBVeto.GetEntries())
print(Wenu_PTV70_140_BFilter.GetEntries())
print(Wenu_PTV140_280_CVetoBVeto.GetEntries())
print(Wenu_PTV140_280_CFilterBVeto.GetEntries())
print(Wenu_PTV140_280_BFilter.GetEntries())
print(Wenu_PTV280_500_CVetoBVeto.GetEntries())
print(Wenu_PTV280_500_CFilterBVeto.GetEntries())
print(Wenu_PTV280_500_BFilter.GetEntries())
print(Wenu_PTV500_1000.GetEntries())
print(Wenu_PTV1000_E_CMS.GetEntries())

# %%
Wtaunu_PTV0_70_CVetoBVeto = ROOT.TChain("mini")
Wtaunu_PTV0_70_CVetoBVeto.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364184.Wtaunu_PTV0_70_CVetoBVeto.1lep.root")
Wtaunu_PTV0_70_CFilterBVeto = ROOT.TChain("mini")
Wtaunu_PTV0_70_CFilterBVeto.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364185.Wtaunu_PTV0_70_CFilterBVeto.1lep.root")
Wtaunu_PTV0_70_BFilter = ROOT.TChain("mini")
Wtaunu_PTV0_70_BFilter.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364186.Wtaunu_PTV0_70_BFilter.1lep.root")
Wtaunu_PTV70_140_CVetoBVeto = ROOT.TChain("mini")
Wtaunu_PTV70_140_CVetoBVeto.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364187.Wtaunu_PTV70_140_CVetoBVeto.1lep.root")
Wtaunu_PTV70_140_CFilterBVeto = ROOT.TChain("mini")
Wtaunu_PTV70_140_CFilterBVeto.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364188.Wtaunu_PTV70_140_CFilterBVeto.1lep.root")
Wtaunu_PTV70_140_BFilter = ROOT.TChain("mini")
Wtaunu_PTV70_140_BFilter.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364189.Wtaunu_PTV70_140_BFilter.1lep.root")
Wtaunu_PTV140_280_CVetoBVeto = ROOT.TChain("mini")
Wtaunu_PTV140_280_CVetoBVeto.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364190.Wtaunu_PTV140_280_CVetoBVeto.1lep.root")
Wtaunu_PTV140_280_CFilterBVeto = ROOT.TChain("mini")
Wtaunu_PTV140_280_CFilterBVeto.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364191.Wtaunu_PTV140_280_CFilterBVeto.1lep.root")
Wtaunu_PTV140_280_BFilter = ROOT.TChain("mini")
Wtaunu_PTV140_280_BFilter.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364192.Wtaunu_PTV140_280_BFilter.1lep.root")
Wtaunu_PTV280_500_CVetoBVeto = ROOT.TChain("mini")
Wtaunu_PTV280_500_CVetoBVeto.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364193.Wtaunu_PTV280_500_CVetoBVeto.1lep.root")
Wtaunu_PTV280_500_CFilterBVeto = ROOT.TChain("mini")
Wtaunu_PTV280_500_CFilterBVeto.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364194.Wtaunu_PTV280_500_CFilterBVeto.1lep.root")
Wtaunu_PTV280_500_BFilter = ROOT.TChain("mini")
Wtaunu_PTV280_500_BFilter.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364195.Wtaunu_PTV280_500_BFilter.1lep.root")
Wtaunu_PTV500_1000 = ROOT.TChain("mini")
Wtaunu_PTV500_1000.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364196.Wtaunu_PTV500_1000.1lep.root")
Wtaunu_PTV1000_E_CMS = ROOT.TChain("mini")
Wtaunu_PTV1000_E_CMS.Add("/opendata/W->lv/MC-2-1lep/MC-2/mc_364197.Wtaunu_PTV1000_E_CMS.1lep.root")

print(Wtaunu_PTV0_70_CVetoBVeto.GetEntries())
print(Wtaunu_PTV0_70_CFilterBVeto.GetEntries())
print(Wtaunu_PTV0_70_BFilter.GetEntries())
print(Wtaunu_PTV70_140_CVetoBVeto.GetEntries())
print(Wtaunu_PTV70_140_CFilterBVeto.GetEntries())
print(Wtaunu_PTV70_140_BFilter.GetEntries())
print(Wtaunu_PTV140_280_CVetoBVeto.GetEntries())
print(Wtaunu_PTV140_280_CFilterBVeto.GetEntries())
print(Wtaunu_PTV140_280_BFilter.GetEntries())
print(Wtaunu_PTV280_500_CVetoBVeto.GetEntries())
print(Wtaunu_PTV280_500_CFilterBVeto.GetEntries())
print(Wtaunu_PTV280_500_BFilter.GetEntries())
print(Wtaunu_PTV500_1000.GetEntries())
print(Wtaunu_PTV1000_E_CMS.GetEntries())

# %%
class Analysis:
    def __init__(self, tree, option):
        self.tree = tree
        self.option = option
        self.accumulated_entries = 0
        

    def begin(self):
        nentries = self.tree.GetEntries()
        print("Processing ",nentries," entries in the "+self.option+" chain")
        self.Tmass = ROOT.TH1F("Tmass_"+self.option,"Invariant mass of W Boson",40,39,180)
    
    def process(self):
        
        for event in self.tree:
            self.accumulated_entries += 1
            
            #check for missing energy >30GeV
            if self.tree.met_et>30000:
                
                #Check for single electron or muon trigger
                if (self.tree.trigM) or (self.tree.trigE):
                    leptemp = ROOT.TLorentzVector()
                    nelectrons = 0
                    nmuons = 0
                    muonindex = -1
                    Wmass = 0
                    
                    #check that there is exactly 1 lepton with pt>35GeV
                    for ilepton in range(self.tree.lep_n):
                        leptemp.SetPtEtaPhiE(self.tree.lep_pt[ilepton], self.tree.lep_eta[ilepton], \
                                              self.tree.lep_phi[ilepton], self.tree.lep_E[ilepton])
                        
                        if self.tree.lep_isTightID[ilepton]:
                            
                            #standard object selection criteria
                            if (self.tree.lep_pt[ilepton]/1000)>35 and \
                            ((self.tree.lep_ptcone30[ilepton]/self.tree.lep_pt[ilepton])<.1) and \
                            ((self.tree.lep_etcone20[ilepton]/self.tree.lep_pt[ilepton])<.1):
                                
                                
                                #electron selection
                                if self.tree.lep_type[ilepton] == 11 and \
                                TMath.Abs(self.tree.lep_eta[ilepton]) < 2.47 and \
                                ((TMath.Abs(self.tree.lep_eta[ilepton])<1.37) or (TMath.Abs(self.tree.lep_eta[ilepton])>1.52)):
                                    
                                    if (TMath.Abs(self.tree.lep_trackd0pvunbiased[ilepton])/self.tree.lep_tracksigd0pvunbiased[ilepton])>5:
                                        continue
                                    if (TMath.Abs(self.tree.lep_z0[ilepton]*math.sin(leptemp.Theta())) > .5):
                                        continue
                                        
                                    nelectrons += 1
                                
                                #muon selection
                                if self.tree.lep_type[ilepton] == 13 and (TMath.Abs(self.tree.lep_eta[ilepton]) < 2.5):
                                    
                                    if (TMath.Abs(self.tree.lep_trackd0pvunbiased[ilepton])/self.tree.lep_tracksigd0pvunbiased[ilepton])>3:
                                        continue
                                    if (TMath.Abs(self.tree.lep_z0[ilepton]*math.sin(leptemp.Theta())) > .5):
                                        continue
                                    
                                    nmuons += 1
                                    muonindex = ilepton
                                                                    
                                    
                    #make sure that lepton is a muon
                    if (nelectrons == 0) and (nmuons == 1):
                        Mvector = ROOT.TLorentzVector()
                        Nvector = ROOT.TLorentzVector()
                        weight = 0
                        
                        #Set muon and neutrino Lorentz vectors
                        Mvector.SetPtEtaPhiE (self.tree.lep_pt[muonindex], self.tree.lep_eta[muonindex], \
                                              self.tree.lep_phi[muonindex], self.tree.lep_E[muonindex])
                        
                        Nvector.SetPtEtaPhiE (self.tree.met_et, 0, self.tree.met_phi, self.tree.met_et)
                        
                        
                        #calculate W boson mass
                        Wmass = math.sqrt(2*Mvector.Pt()*Nvector.Et()*(1-math.cos(Mvector.DeltaPhi(Nvector))))
                        
                        
                        
                        #fill histograms
                        if Wmass >60000:
                            if self.option == "data":
                                weight = 1

                            if self.option != "data":
                                weight = (self.tree.mcWeight * self.tree.scaleFactor_PILEUP *\
                                          self.tree.scaleFactor_LepTRIGGER * self.tree.scaleFactor_MUON * \
                                          self.tree.scaleFactor_ELE)
                                
                            
                            self.Tmass.Fill(Wmass/1000, weight)

                        
                        
            if (self.accumulated_entries%1000000 == 1):
                print("Processed: ",self.accumulated_entries)

            
    def terminate(self):
        
        output_name = "output/WlvAnalysis_"+self.option+".root"
        print("Saving to file "+output_name)
        file = ROOT.TFile(output_name, "RECREATE")
        self.Tmass.Write()
        file.Close()
        print("Done saving!")

# %%
pdata=Analysis(data,"data")
pdata.begin()
pdata.process()
pdata.terminate()

# %%
pZee=Analysis(Zee,"Zee")
pZee.begin()
pZee.process()
pZee.terminate()

pZmumu=Analysis(Zmumu,"Zmumu")
pZmumu.begin()
pZmumu.process()
pZmumu.terminate()

pZtautau=Analysis(Ztautau,"Ztautau")
pZtautau.begin()
pZtautau.process()
pZtautau.terminate()

pZqqZll=Analysis(ZqqZll,"ZqqZll")
pZqqZll.begin()
pZqqZll.process()
pZqqZll.terminate()

pWqqZll=Analysis(WqqZll,"WqqZll")
pWqqZll.begin()
pWqqZll.process()
pWqqZll.terminate()

pWpqqWmlv=Analysis(WpqqWmlv,"WpqqWmlv")
pWpqqWmlv.begin()
pWpqqWmlv.process()
pWpqqWmlv.terminate()

pWplvWmqq=Analysis(WplvWmqq,"WplvWmqq")
pWplvWmqq.begin()
pWplvWmqq.process()
pWplvWmqq.terminate()

pWlvZqq=Analysis(WlvZqq,"WlvZqq")
pWlvZqq.begin()
pWlvZqq.process()
pWlvZqq.terminate()

pllll=Analysis(llll,"llll")
pllll.begin()
pllll.process()
pllll.terminate()

plllv=Analysis(lllv,"lllv")
plllv.begin()
plllv.process()
plllv.terminate()

pllvv=Analysis(llvv,"llvv")
pllvv.begin()
pllvv.process()
pllvv.terminate()

plvvv=Analysis(lvvv,"lvvv")
plvvv.begin()
plvvv.process()
plvvv.terminate()

pttbar_lep=Analysis(ttbar_lep,"ttbar_lep")
pttbar_lep.begin()
pttbar_lep.process()
pttbar_lep.terminate()

psingle_top_tchan=Analysis(single_top_tchan,"single_top_tchan")
psingle_top_tchan.begin()
psingle_top_tchan.process()
psingle_top_tchan.terminate()

psingle_antitop_tchan=Analysis(single_antitop_tchan,"single_antitop_tchan")
psingle_antitop_tchan.begin()
psingle_antitop_tchan.process()
psingle_antitop_tchan.terminate()

psingle_top_wtchan=Analysis(single_top_wtchan,"single_top_wtchan")
psingle_top_wtchan.begin()
psingle_top_wtchan.process()
psingle_top_wtchan.terminate()

psingle_antitop_wtchan=Analysis(single_antitop_wtchan,"single_antitop_wtchan")
psingle_antitop_wtchan.begin()
psingle_antitop_wtchan.process()
psingle_antitop_wtchan.terminate()

psingle_top_schan=Analysis(single_top_schan,"single_top_schan")
psingle_top_schan.begin()
psingle_top_schan.process()
psingle_top_schan.terminate()

psingle_antitop_schan=Analysis(single_antitop_schan,"single_antitop_schan")
psingle_antitop_schan.begin()
psingle_antitop_schan.process()
psingle_antitop_schan.terminate()

pWmunu_PTV0_70_CVetoBVeto=Analysis(Wmunu_PTV0_70_CVetoBVeto,"Wmunu_PTV0_70_CVetoBVeto")
pWmunu_PTV0_70_CVetoBVeto.begin()
pWmunu_PTV0_70_CVetoBVeto.process()
pWmunu_PTV0_70_CVetoBVeto.terminate()

pWmunu_PTV0_70_CFilterBVeto=Analysis(Wmunu_PTV0_70_CFilterBVeto,"Wmunu_PTV0_70_CFilterBVeto")
pWmunu_PTV0_70_CFilterBVeto.begin()
pWmunu_PTV0_70_CFilterBVeto.process()
pWmunu_PTV0_70_CFilterBVeto.terminate()

pWmunu_PTV0_70_BFilter=Analysis(Wmunu_PTV0_70_BFilter,"Wmunu_PTV0_70_BFilter")
pWmunu_PTV0_70_BFilter.begin()
pWmunu_PTV0_70_BFilter.process()
pWmunu_PTV0_70_BFilter.terminate()

pWmunu_PTV70_140_CVetoBVeto=Analysis(Wmunu_PTV70_140_CVetoBVeto,"Wmunu_PTV70_140_CVetoBVeto")
pWmunu_PTV70_140_CVetoBVeto.begin()
pWmunu_PTV70_140_CVetoBVeto.process()
pWmunu_PTV70_140_CVetoBVeto.terminate()

pWmunu_PTV70_140_CFilterBVeto=Analysis(Wmunu_PTV70_140_CFilterBVeto,"Wmunu_PTV70_140_CFilterBVeto")
pWmunu_PTV70_140_CFilterBVeto.begin()
pWmunu_PTV70_140_CFilterBVeto.process()
pWmunu_PTV70_140_CFilterBVeto.terminate()

pWmunu_PTV70_140_BFilter=Analysis(Wmunu_PTV70_140_BFilter,"Wmunu_PTV70_140_BFilter")
pWmunu_PTV70_140_BFilter.begin()
pWmunu_PTV70_140_BFilter.process()
pWmunu_PTV70_140_BFilter.terminate()

pWmunu_PTV140_280_CVetoBVeto=Analysis(Wmunu_PTV140_280_CVetoBVeto,"Wmunu_PTV140_280_CVetoBVeto")
pWmunu_PTV140_280_CVetoBVeto.begin()
pWmunu_PTV140_280_CVetoBVeto.process()
pWmunu_PTV140_280_CVetoBVeto.terminate()

pWmunu_PTV140_280_CFilterBVeto=Analysis(Wmunu_PTV140_280_CFilterBVeto,"Wmunu_PTV140_280_CFilterBVeto")
pWmunu_PTV140_280_CFilterBVeto.begin()
pWmunu_PTV140_280_CFilterBVeto.process()
pWmunu_PTV140_280_CFilterBVeto.terminate()

pWmunu_PTV140_280_BFilter=Analysis(Wmunu_PTV140_280_BFilter,"Wmunu_PTV140_280_BFilter")
pWmunu_PTV140_280_BFilter.begin()
pWmunu_PTV140_280_BFilter.process()
pWmunu_PTV140_280_BFilter.terminate()

pWmunu_PTV280_500_CVetoBVeto=Analysis(Wmunu_PTV280_500_CVetoBVeto,"Wmunu_PTV280_500_CVetoBVeto")
pWmunu_PTV280_500_CVetoBVeto.begin()
pWmunu_PTV280_500_CVetoBVeto.process()
pWmunu_PTV280_500_CVetoBVeto.terminate()

pWmunu_PTV280_500_CFilterBVeto=Analysis(Wmunu_PTV280_500_CFilterBVeto,"Wmunu_PTV280_500_CFilterBVeto")
pWmunu_PTV280_500_CFilterBVeto.begin()
pWmunu_PTV280_500_CFilterBVeto.process()
pWmunu_PTV280_500_CFilterBVeto.terminate()

pWmunu_PTV280_500_BFilter=Analysis(Wmunu_PTV280_500_BFilter,"Wmunu_PTV280_500_BFilter")
pWmunu_PTV280_500_BFilter.begin()
pWmunu_PTV280_500_BFilter.process()
pWmunu_PTV280_500_BFilter.terminate()

pWmunu_PTV500_1000=Analysis(Wmunu_PTV500_1000,"Wmunu_PTV500_1000")
pWmunu_PTV500_1000.begin()
pWmunu_PTV500_1000.process()
pWmunu_PTV500_1000.terminate()

pWmunu_PTV1000_E_CMS=Analysis(Wmunu_PTV1000_E_CMS,"Wmunu_PTV1000_E_CMS")
pWmunu_PTV1000_E_CMS.begin()
pWmunu_PTV1000_E_CMS.process()
pWmunu_PTV1000_E_CMS.terminate()

pWenu_PTV0_70_CVetoBVeto=Analysis(Wenu_PTV0_70_CVetoBVeto,"Wenu_PTV0_70_CVetoBVeto")
pWenu_PTV0_70_CVetoBVeto.begin()
pWenu_PTV0_70_CVetoBVeto.process()
pWenu_PTV0_70_CVetoBVeto.terminate()

pWenu_PTV0_70_CFilterBVeto=Analysis(Wenu_PTV0_70_CFilterBVeto,"Wenu_PTV0_70_CFilterBVeto")
pWenu_PTV0_70_CFilterBVeto.begin()
pWenu_PTV0_70_CFilterBVeto.process()
pWenu_PTV0_70_CFilterBVeto.terminate()

pWenu_PTV0_70_BFilter=Analysis(Wenu_PTV0_70_BFilter,"Wenu_PTV0_70_BFilter")
pWenu_PTV0_70_BFilter.begin()
pWenu_PTV0_70_BFilter.process()
pWenu_PTV0_70_BFilter.terminate()

pWenu_PTV70_140_CVetoBVeto=Analysis(Wenu_PTV70_140_CVetoBVeto,"Wenu_PTV70_140_CVetoBVeto")
pWenu_PTV70_140_CVetoBVeto.begin()
pWenu_PTV70_140_CVetoBVeto.process()
pWenu_PTV70_140_CVetoBVeto.terminate()

pWenu_PTV70_140_CFilterBVeto=Analysis(Wenu_PTV70_140_CFilterBVeto,"Wenu_PTV70_140_CFilterBVeto")
pWenu_PTV70_140_CFilterBVeto.begin()
pWenu_PTV70_140_CFilterBVeto.process()
pWenu_PTV70_140_CFilterBVeto.terminate()

pWenu_PTV70_140_BFilter=Analysis(Wenu_PTV70_140_BFilter,"Wenu_PTV70_140_BFilter")
pWenu_PTV70_140_BFilter.begin()
pWenu_PTV70_140_BFilter.process()
pWenu_PTV70_140_BFilter.terminate()

pWenu_PTV140_280_CVetoBVeto=Analysis(Wenu_PTV140_280_CVetoBVeto,"Wenu_PTV140_280_CVetoBVeto")
pWenu_PTV140_280_CVetoBVeto.begin()
pWenu_PTV140_280_CVetoBVeto.process()
pWenu_PTV140_280_CVetoBVeto.terminate()

pWenu_PTV140_280_CFilterBVeto=Analysis(Wenu_PTV140_280_CFilterBVeto,"Wenu_PTV140_280_CFilterBVeto")
pWenu_PTV140_280_CFilterBVeto.begin()
pWenu_PTV140_280_CFilterBVeto.process()
pWenu_PTV140_280_CFilterBVeto.terminate()

pWenu_PTV140_280_BFilter=Analysis(Wenu_PTV140_280_BFilter,"Wenu_PTV140_280_BFilter")
pWenu_PTV140_280_BFilter.begin()
pWenu_PTV140_280_BFilter.process()
pWenu_PTV140_280_BFilter.terminate()

pWenu_PTV280_500_CVetoBVeto=Analysis(Wenu_PTV280_500_CVetoBVeto,"Wenu_PTV280_500_CVetoBVeto")
pWenu_PTV280_500_CVetoBVeto.begin()
pWenu_PTV280_500_CVetoBVeto.process()
pWenu_PTV280_500_CVetoBVeto.terminate()

pWenu_PTV280_500_CFilterBVeto=Analysis(Wenu_PTV280_500_CFilterBVeto,"Wenu_PTV280_500_CFilterBVeto")
pWenu_PTV280_500_CFilterBVeto.begin()
pWenu_PTV280_500_CFilterBVeto.process()
pWenu_PTV280_500_CFilterBVeto.terminate()

pWenu_PTV280_500_BFilter=Analysis(Wenu_PTV280_500_BFilter,"Wenu_PTV280_500_BFilter")
pWenu_PTV280_500_BFilter.begin()
pWenu_PTV280_500_BFilter.process()
pWenu_PTV280_500_BFilter.terminate()

pWenu_PTV500_1000=Analysis(Wenu_PTV500_1000,"Wenu_PTV500_1000")
pWenu_PTV500_1000.begin()
pWenu_PTV500_1000.process()
pWenu_PTV500_1000.terminate()

pWenu_PTV1000_E_CMS=Analysis(Wenu_PTV1000_E_CMS,"Wenu_PTV1000_E_CMS")
pWenu_PTV1000_E_CMS.begin()
pWenu_PTV1000_E_CMS.process()
pWenu_PTV1000_E_CMS.terminate()

pWtaunu_PTV0_70_CVetoBVeto=Analysis(Wtaunu_PTV0_70_CVetoBVeto,"Wtaunu_PTV0_70_CVetoBVeto")
pWtaunu_PTV0_70_CVetoBVeto.begin()
pWtaunu_PTV0_70_CVetoBVeto.process()
pWtaunu_PTV0_70_CVetoBVeto.terminate()

pWtaunu_PTV0_70_CFilterBVeto=Analysis(Wtaunu_PTV0_70_CFilterBVeto,"Wtaunu_PTV0_70_CFilterBVeto")
pWtaunu_PTV0_70_CFilterBVeto.begin()
pWtaunu_PTV0_70_CFilterBVeto.process()
pWtaunu_PTV0_70_CFilterBVeto.terminate()

pWtaunu_PTV0_70_BFilter=Analysis(Wtaunu_PTV0_70_BFilter,"Wtaunu_PTV0_70_BFilter")
pWtaunu_PTV0_70_BFilter.begin()
pWtaunu_PTV0_70_BFilter.process()
pWtaunu_PTV0_70_BFilter.terminate()

pWtaunu_PTV70_140_CVetoBVeto=Analysis(Wtaunu_PTV70_140_CVetoBVeto,"Wtaunu_PTV70_140_CVetoBVeto")
pWtaunu_PTV70_140_CVetoBVeto.begin()
pWtaunu_PTV70_140_CVetoBVeto.process()
pWtaunu_PTV70_140_CVetoBVeto.terminate()

pWtaunu_PTV70_140_CFilterBVeto=Analysis(Wtaunu_PTV70_140_CFilterBVeto,"Wtaunu_PTV70_140_CFilterBVeto")
pWtaunu_PTV70_140_CFilterBVeto.begin()
pWtaunu_PTV70_140_CFilterBVeto.process()
pWtaunu_PTV70_140_CFilterBVeto.terminate()

pWtaunu_PTV70_140_BFilter=Analysis(Wtaunu_PTV70_140_BFilter,"Wtaunu_PTV70_140_BFilter")
pWtaunu_PTV70_140_BFilter.begin()
pWtaunu_PTV70_140_BFilter.process()
pWtaunu_PTV70_140_BFilter.terminate()

pWtaunu_PTV140_280_CVetoBVeto=Analysis(Wtaunu_PTV140_280_CVetoBVeto,"Wtaunu_PTV140_280_CVetoBVeto")
pWtaunu_PTV140_280_CVetoBVeto.begin()
pWtaunu_PTV140_280_CVetoBVeto.process()
pWtaunu_PTV140_280_CVetoBVeto.terminate()

pWtaunu_PTV140_280_CFilterBVeto=Analysis(Wtaunu_PTV140_280_CFilterBVeto,"Wtaunu_PTV140_280_CFilterBVeto")
pWtaunu_PTV140_280_CFilterBVeto.begin()
pWtaunu_PTV140_280_CFilterBVeto.process()
pWtaunu_PTV140_280_CFilterBVeto.terminate()

pWtaunu_PTV140_280_BFilter=Analysis(Wtaunu_PTV140_280_BFilter,"Wtaunu_PTV140_280_BFilter")
pWtaunu_PTV140_280_BFilter.begin()
pWtaunu_PTV140_280_BFilter.process()
pWtaunu_PTV140_280_BFilter.terminate()

pWtaunu_PTV280_500_CVetoBVeto=Analysis(Wtaunu_PTV280_500_CVetoBVeto,"Wtaunu_PTV280_500_CVetoBVeto")
pWtaunu_PTV280_500_CVetoBVeto.begin()
pWtaunu_PTV280_500_CVetoBVeto.process()
pWtaunu_PTV280_500_CVetoBVeto.terminate()

pWtaunu_PTV280_500_CFilterBVeto=Analysis(Wtaunu_PTV280_500_CFilterBVeto,"Wtaunu_PTV280_500_CFilterBVeto")
pWtaunu_PTV280_500_CFilterBVeto.begin()
pWtaunu_PTV280_500_CFilterBVeto.process()
pWtaunu_PTV280_500_CFilterBVeto.terminate()

pWtaunu_PTV280_500_BFilter=Analysis(Wtaunu_PTV280_500_BFilter,"Wtaunu_PTV280_500_BFilter")
pWtaunu_PTV280_500_BFilter.begin()
pWtaunu_PTV280_500_BFilter.process()
pWtaunu_PTV280_500_BFilter.terminate()

pWtaunu_PTV500_1000=Analysis(Wtaunu_PTV500_1000,"Wtaunu_PTV500_1000")
pWtaunu_PTV500_1000.begin()
pWtaunu_PTV500_1000.process()
pWtaunu_PTV500_1000.terminate()

pWtaunu_PTV1000_E_CMS=Analysis(Wtaunu_PTV1000_E_CMS,"Wtaunu_PTV1000_E_CMS")
pWtaunu_PTV1000_E_CMS.begin()
pWtaunu_PTV1000_E_CMS.process()
pWtaunu_PTV1000_E_CMS.terminate()

# %%
MCchains = ["data", "Zee", "Zmumu", "Ztautau", "ZqqZll", "WqqZll", "WpqqWmlv", "WplvWmqq", "WlvZqq","llll","lllv","llvv", \
            "lvvv","ttbar_lep","single_top_tchan","single_antitop_tchan","single_top_wtchan","single_antitop_wtchan", \
           "single_top_schan","single_antitop_schan","Wmunu_PTV0_70_CVetoBVeto","Wmunu_PTV0_70_CFilterBVeto", \
           "Wmunu_PTV0_70_BFilter","Wmunu_PTV70_140_CVetoBVeto","Wmunu_PTV70_140_CFilterBVeto","Wmunu_PTV70_140_BFilter",\
           "Wmunu_PTV140_280_CVetoBVeto","Wmunu_PTV140_280_CFilterBVeto","Wmunu_PTV140_280_BFilter","Wmunu_PTV280_500_CVetoBVeto", \
           "Wmunu_PTV280_500_CFilterBVeto","Wmunu_PTV280_500_BFilter","Wmunu_PTV500_1000","Wmunu_PTV1000_E_CMS", \
           "Wenu_PTV0_70_CVetoBVeto","Wenu_PTV0_70_CFilterBVeto","Wenu_PTV0_70_BFilter","Wenu_PTV70_140_CVetoBVeto", \
           "Wenu_PTV70_140_CFilterBVeto","Wenu_PTV70_140_BFilter","Wenu_PTV140_280_CVetoBVeto","Wenu_PTV140_280_CFilterBVeto", \
           "Wenu_PTV140_280_BFilter","Wenu_PTV280_500_CVetoBVeto","Wenu_PTV280_500_CFilterBVeto","Wenu_PTV280_500_BFilter", \
           "Wenu_PTV500_1000","Wenu_PTV1000_E_CMS","Wtaunu_PTV0_70_CVetoBVeto","Wtaunu_PTV0_70_CFilterBVeto", \
           "Wtaunu_PTV0_70_BFilter","Wtaunu_PTV70_140_CVetoBVeto","Wtaunu_PTV70_140_CFilterBVeto","Wtaunu_PTV70_140_BFilter", \
           "Wtaunu_PTV140_280_CVetoBVeto","Wtaunu_PTV140_280_CFilterBVeto","Wtaunu_PTV140_280_BFilter","Wtaunu_PTV280_500_CVetoBVeto", \
           "Wtaunu_PTV280_500_CFilterBVeto","Wtaunu_PTV280_500_BFilter","Wtaunu_PTV500_1000","Wtaunu_PTV1000_E_CMS"]


lum = 10064

scalefactors = {"data":1, "Zee":(lum*1950.5295/150277594200), "Zmumu":(lum*1950.6321/147334691090), \
                "Ztautau":(lum*1950.6321/56171652547.3), "ZqqZll":(lum*2.20355112/3439266.11559), \
                "WqqZll":(lum*3.4328/241438.72705), "WpqqWmlv":(lum*24.708/998250.783475), \
                "WplvWmqq":(lum*24.724/1069526.41899), "WlvZqq":(lum*11.42/1111991.15979), \
                "llll":(lum*1.2578/7538705.8077),"lllv":(lum*4.6049/5441475.00407),"llvv":(lum*12.466/5039259.9696), \
                "lvvv":(lum*3.2286/1727991.07441),"ttbar_lep":(lum*452.693559/49296600), \
                "single_top_tchan":(lum*44.152/4986200),"single_antitop_tchan":(lum*26.276/4989800), \
                "single_top_wtchan":(lum*35.845486/4865800),"single_antitop_wtchan":(lum*35.824406/4945600), \
               "single_top_schan":(lum*2.06121/997800),"single_antitop_schan":(lum*1.288662/995400), \
                "Wmunu_PTV0_70_CVetoBVeto":(lum*15317.171239/16619290.3298),"Wmunu_PTV0_70_CFilterBVeto":(lum*2431.204019/5643599.11526), \
               "Wmunu_PTV0_70_BFilter":(lum*828.465384/10403012.6599),"Wmunu_PTV70_140_CVetoBVeto":(lum*617.439593/5418398.88082), \
                "Wmunu_PTV70_140_CFilterBVeto":(lum*225.006704/3693885.78953),"Wmunu_PTV70_140_BFilter":(lum*76.213179/7990084.35926),\
               "Wmunu_PTV140_280_CVetoBVeto":(lum*198.635592/6155495.28527),"Wmunu_PTV140_280_CFilterBVeto":(lum*96.233222/5260811.17463), \
                "Wmunu_PTV140_280_BFilter":(lum*36.348467/7271557.26566),"Wmunu_PTV280_500_CVetoBVeto":(lum*38.299835/4325283.67358), \
               "Wmunu_PTV280_500_CFilterBVeto":(lum*22.395647/2783968.68238),"Wmunu_PTV280_500_BFilter":(lum*8.768196/2835707.22044), \
                "Wmunu_PTV500_1000":(lum*14.558821/5941704.99235),"Wmunu_PTV1000_E_CMS":(lum*1.198003/4068015.22447), \
               "Wenu_PTV0_70_CVetoBVeto":(lum*15324.216356/16615214.8608),"Wenu_PTV0_70_CFilterBVeto":(lum*2430.656322/5647044.71225), \
                "Wenu_PTV0_70_BFilter":(lum*832.203758/10407897.8772),"Wenu_PTV70_140_CVetoBVeto":(lum*618.6882/5098540.19503), \
               "Wenu_PTV70_140_CFilterBVeto":(lum*223.63946/3661915.17878),"Wenu_PTV70_140_BFilter":(lum*94.875534/3980401.78673), \
                "Wenu_PTV140_280_CVetoBVeto":(lum*197.343129/6121546.03361),"Wenu_PTV140_280_CFilterBVeto":(lum*96.277568/5263243.42582), \
               "Wenu_PTV140_280_BFilter":(lum*35.917295/7327201.08884),"Wenu_PTV280_500_CVetoBVeto":(lum*38.340533/4312357.01458), \
                "Wenu_PTV280_500_CFilterBVeto":(lum*22.36999/2778654.28759),"Wenu_PTV280_500_BFilter":(lum*9.586345/2835314.68179), \
               "Wenu_PTV500_1000":(lum*14.598599/6003269.52809),"Wenu_PTV1000_E_CMS":(lum*1.197518/4075236.23897), \
                "Wtaunu_PTV0_70_CVetoBVeto":(lum*15324.887336/11929044.1188),"Wtaunu_PTV0_70_CFilterBVeto":(lum*2443.425881/5671521.55269), \
               "Wtaunu_PTV0_70_BFilter":(lum*837.531038/10498770.1084),"Wtaunu_PTV70_140_CVetoBVeto":(lum*620.166885/5427023.47527), \
                "Wtaunu_PTV70_140_CFilterBVeto":(lum*222.595303/3719117.16117),"Wtaunu_PTV70_140_BFilter":(lum*95.365521/3969118.20687), \
               "Wtaunu_PTV140_280_CVetoBVeto":(lum*197.370776/6166514.76606),"Wtaunu_PTV140_280_CFilterBVeto":(lum*93.808553/5085280.31607), \
                "Wtaunu_PTV140_280_BFilter":(lum*34.639523/7291603.73991),"Wtaunu_PTV280_500_CVetoBVeto":(lum*38.34009/4322848.66983), \
               "Wtaunu_PTV280_500_CFilterBVeto":(lum*22.268425/2772305.06916),"Wtaunu_PTV280_500_BFilter":(lum*9.490847/2830341.62344), \
                "Wtaunu_PTV500_1000":(lum*14.60345/5932750.60186),"Wtaunu_PTV1000_E_CMS":(lum*1.197324/4057477.95297)}

# %%
#scaling histograms
canvases = {}
files = {}
histos = {}


for tag in MCchains:
    filename = "output/WlvAnalysis_"+tag+".root"
    print("Opening "+filename)
    files[tag] = ROOT.TFile(filename,"READ")
    histo=files[tag].Get("Tmass_"+tag)
    histo.Scale(scalefactors[tag])
    histo.SetStats(0)
    histos["Tmass_"+tag] = histo
# Out:
# Opening output/WlvAnalysis_data.root
# Opening output/WlvAnalysis_Zee.root
# Opening output/WlvAnalysis_Zmumu.root
# Opening output/WlvAnalysis_Ztautau.root
# Opening output/WlvAnalysis_ZqqZll.root
# Opening output/WlvAnalysis_WqqZll.root
# Opening output/WlvAnalysis_WpqqWmlv.root
# Opening output/WlvAnalysis_WplvWmqq.root
# Opening output/WlvAnalysis_WlvZqq.root
# Opening output/WlvAnalysis_llll.root
# Opening output/WlvAnalysis_lllv.root
# Opening output/WlvAnalysis_llvv.root
# Opening output/WlvAnalysis_lvvv.root
# Opening output/WlvAnalysis_ttbar_lep.root
# Opening output/WlvAnalysis_single_top_tchan.root
# Opening output/WlvAnalysis_single_antitop_tchan.root
# Opening output/WlvAnalysis_single_top_wtchan.root
# Opening output/WlvAnalysis_single_antitop_wtchan.root
# Opening output/WlvAnalysis_single_top_schan.root
# Opening output/WlvAnalysis_single_antitop_schan.root
# Opening output/WlvAnalysis_Wmunu_PTV0_70_CVetoBVeto.root
# ...

# %%
#W+jets MC


Wjets = ROOT.TH1F("Wjets","Invariant mass of W Boson",40,39,180)

Wjetslist = ["Wmunu_PTV0_70_CVetoBVeto","Wmunu_PTV0_70_CFilterBVeto", \
             "Wmunu_PTV0_70_BFilter","Wmunu_PTV70_140_CVetoBVeto","Wmunu_PTV70_140_CFilterBVeto","Wmunu_PTV70_140_BFilter",\
           "Wmunu_PTV140_280_CVetoBVeto","Wmunu_PTV140_280_CFilterBVeto","Wmunu_PTV140_280_BFilter","Wmunu_PTV280_500_CVetoBVeto", \
           "Wmunu_PTV280_500_CFilterBVeto","Wmunu_PTV280_500_BFilter","Wmunu_PTV500_1000","Wmunu_PTV1000_E_CMS", \
           "Wenu_PTV0_70_CVetoBVeto","Wenu_PTV0_70_CFilterBVeto","Wenu_PTV0_70_BFilter","Wenu_PTV70_140_CVetoBVeto", \
           "Wenu_PTV70_140_CFilterBVeto","Wenu_PTV70_140_BFilter","Wenu_PTV140_280_CVetoBVeto","Wenu_PTV140_280_CFilterBVeto", \
           "Wenu_PTV140_280_BFilter","Wenu_PTV280_500_CVetoBVeto","Wenu_PTV280_500_CFilterBVeto","Wenu_PTV280_500_BFilter", \
           "Wenu_PTV500_1000","Wenu_PTV1000_E_CMS","Wtaunu_PTV0_70_CVetoBVeto","Wtaunu_PTV0_70_CFilterBVeto", \
           "Wtaunu_PTV0_70_BFilter","Wtaunu_PTV70_140_CVetoBVeto","Wtaunu_PTV70_140_CFilterBVeto","Wtaunu_PTV70_140_BFilter", \
           "Wtaunu_PTV140_280_CVetoBVeto","Wtaunu_PTV140_280_CFilterBVeto","Wtaunu_PTV140_280_BFilter","Wtaunu_PTV280_500_CVetoBVeto", \
           "Wtaunu_PTV280_500_CFilterBVeto","Wtaunu_PTV280_500_BFilter","Wtaunu_PTV500_1000","Wtaunu_PTV1000_E_CMS"]


for tags in Wjetslist:
    Wjets.Add(histos["Tmass_"+tags])

# %%
#single top MC

singletoplist = ["single_top_tchan","single_antitop_tchan","single_top_wtchan","single_antitop_wtchan", \
           "single_top_schan","single_antitop_schan"]
singletop = ROOT.TH1F("singletop","Invariant mass of W Boson",40,39,180)

for tags in singletoplist:
    singletop.Add(histos["Tmass_"+tags])

# %%
#ttbar


ttbar = ROOT.TH1F("ttbar","Invariant mass of W Boson",40,39,180)
ttbar.Add(histos["Tmass_ttbar_lep"])
# Out:
# True

# %%
#Diboson

dibosonlist = ["ZqqZll", "WqqZll", "WpqqWmlv", "WplvWmqq", "WlvZqq","llll","lllv","llvv", "lvvv"]
Diboson = ROOT.TH1F("diboson","Invariant mass of W Boson",40,39,180)

for tags in dibosonlist:
    Diboson.Add(histos["Tmass_"+tags])

# %%
#Z+jets

zjetslist = ["Zee", "Zmumu","Ztautau"]
Zjets = ROOT.TH1F("Zjets","Invariant mass of W Boson",40,39,180)

for tags in zjetslist:
    Zjets.Add(histos["Tmass_"+tags])

# %%
#make mcforchisquared
testcanvas10 = ROOT.TCanvas("testcanvas10","Canvas for Tmass data", 600, 800)
MCforchisquared = ROOT.TH1F("MCforchisquared","Invariant mass of W Boson",40,39,180)


MCforchisquared.Add(singletop)
MCforchisquared.Add(ttbar)
MCforchisquared.Add(Diboson)
MCforchisquared.Add(Zjets)
MCforchisquared.Add(Wjets)

MCforchisquared.SetFillStyle(3154)
MCforchisquared.SetFillColor(ROOT.kBlue+2)
MCforchisquared.SetLineColor(ROOT.kBlack)
MCforchisquared.SetLineWidth(2)
MCforchisquared.SetMarkerSize(0)
MCforchisquared.SetLineColor(ROOT.kWhite)

# %%
#Stack the MC histo's 
#make the legend
testcanvas6 = ROOT.TCanvas("testcanvas6","Canvas for Tmass data", 800, 600)
MC = ROOT.THStack("MCstack","W Boson Transverse Mass")


legend=ROOT.TLegend(0.7,0.5,0.93,0.925)
legend.SetFillStyle(0)
legend.SetBorderSize(0)
legend.SetTextAlign(32)
legend.SetTextFont(42)
legend.SetTextSize(0.05)
legend.SetMargin(0.22)
legend.SetTextAlign(32)
legend.AddEntry(histos["Tmass_data"],"Data","lep")
legend.AddEntry(Wjets,"W+jets","f")
legend.AddEntry(Zjets,"Z+jets","f")
legend.AddEntry(singletop,"Single top","f")
legend.AddEntry(ttbar,"t#bar{t}","f")
legend.AddEntry(Diboson,"Diboson","f")
legend.AddEntry(MCforchisquared, "MC stat. unc", "f")



Wjets.SetFillStyle(1001)
Wjets.SetFillColor(ROOT.kGreen-3)
Wjets.SetLineColor(ROOT.kGreen-3)

Zjets.SetFillStyle(1001)
Zjets.SetFillColor(6)
Zjets.SetLineColor(6)

singletop.SetFillStyle(1001)
singletop.SetFillColor(7)
singletop.SetLineColor(7)

ttbar.SetFillStyle(1001)
ttbar.SetFillColor(ROOT.kOrange+7)
ttbar.SetLineColor(ROOT.kOrange+7)

Diboson.SetFillStyle(1001)
Diboson.SetFillColor(ROOT.kViolet+7)
Diboson.SetLineColor(ROOT.kViolet+7)

MC.Add(singletop)
MC.Add(ttbar)
MC.Add(Diboson)
MC.Add(Zjets)
MC.Add(Wjets)


MC.Draw("hist")
legend.Draw()
MC.GetXaxis().SetTitle("Transverse Mass(GeV)")
MC.GetYaxis().SetTitle("Events/bin")
MC.GetYaxis().SetLabelSize(0.045)
MC.GetYaxis().SetTitleSize(0.05)
MC.GetYaxis().SetTitleOffset(0.7)
MC.SetMinimum(10)
MC.SetMaximum(8e6)
MC.Draw("hist")
legend.Draw()
#testcanvas6.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: testcanvas6

# %%
#make figure h from technical note

ROOT.gROOT.SetStyle("ATLAS")
fhisto = ROOT.TCanvas("fhisto", "", 600, 800)
mainplot = ROOT.TPad("mainplot","",0,0.25,1,1)
ratioplot = ROOT.TPad("ratioplot","", 0, 0, 1, .25)
mainplot.SetTickx(False)
mainplot.SetTicky(False)
mainplot.SetLeftMargin(.14)
mainplot.SetRightMargin(.05)
mainplot.SetBottomMargin(0)
ratioplot.SetTickx(False)
ratioplot.SetTicky(False)
ratioplot.SetLeftMargin(.14)
ratioplot.SetRightMargin(.05)
ratioplot.SetTopMargin(0)
ratioplot.SetBottomMargin(0.3)
mainplot.Draw()
ratioplot.Draw()
fhisto.Draw()

#upper pad
mainplot.cd()


MC.Draw("hist")

histos["Tmass_data"].SetMarkerStyle(20)
histos["Tmass_data"].SetMarkerSize(.8)
histos["Tmass_data"].SetLineWidth(2)
histos["Tmass_data"].SetLineColor(ROOT.kBlack)
histos["Tmass_data"].SetStats(0)
histos["Tmass_data"].SetMinimum(1e-3)
histos["Tmass_data"].SetMaximum(8e6)
histos["Tmass_data"].Draw("same")
MCforchisquared.Draw("e2same")


legend.Draw()

#lower pad
ratioplot.cd()



dataclone = histos["Tmass_data"].Clone()
dataclone.SetMinimum(1e-3)
dataclone.SetMaximum(2)
MCforratio = ROOT.TH1F("MCforratio","",40,39,180)

for tags in MCchains:
    if tags != "data":
        MCforratio.Add(histos["Tmass_"+tags])

dataclone.Divide(MCforratio)
dataclone.GetYaxis().SetTitle("Data / Pred")
dataclone.GetXaxis().SetTitle("M_{T}[GeV]")
dataclone.GetYaxis().SetLabelSize(0.045)
dataclone.GetXaxis().SetLabelSize(0.1)
dataclone.GetXaxis().SetTitleSize(0.15)
dataclone.GetXaxis().SetTitleOffset(1.1)
dataclone.GetYaxis().SetTitleSize(0.13)
dataclone.GetYaxis().SetTitleOffset(0.3)
dataclone.GetYaxis().SetNdivisions(503, False)
dataclone.SetTitle("")
dataclone.Draw()

#lines at 1/2, 1, 1&1/2
onehalf = ROOT.TF1("onehalf", "1/2", 39, 180)
onehalf.SetLineStyle(2)
onehalf.SetLineWidth(1)
onehalf.SetLineColor(4)
onehalf.Draw("SAME")

one = ROOT.TF1("one", "1", 39, 180)
one.SetLineWidth(1)
one.SetLineColor(35)
one.Draw("SAME")

oneandonehalf = ROOT.TF1("oneandonehalf", "3/2", 39, 180)
oneandonehalf.SetLineStyle(2)
oneandonehalf.SetLineWidth(1)
oneandonehalf.SetLineColor(4)
oneandonehalf.Draw("SAME")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: fhisto
# Warning in <TFile::Append>: Replacing existing TH1: MCforratio (Potential memory leak).
# <div id="root_plot_4"
#      style="width: 596px; height: 772px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
#Breit-Wigner fit

testcanvas11 = ROOT.TCanvas("testcanvas11","Canvas for Tmass data", 600, 800)

dataclone1 = histos["Tmass_data"].Clone()
pi = TMath.Pi()

BreitWigner = ROOT.TF1("BreitWigner", "(([0]*[1]*[2])/(pi))*(((x**2 - [1]**2)**2 +([1]*[2])**2)**-1)", 70.72, 95.40)

BreitWigner.SetParameter(0,2e+10)
BreitWigner.SetParameter(1, 80)
BreitWigner.SetParameter(2, 10)



dataclone1.Fit("BreitWigner", "", "", 70.72, 95.40)

dataclone1.Draw()
testcanvas11.Draw()
# Out:
#  FCN=10922.9 FROM MIGRAD    STATUS=CONVERGED     120 CALLS         121 TOTAL
#                      EDM=1.44004e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.66806e+10   1.67073e+07   1.27223e+04   1.73514e-10
#    2  p1           7.80731e+01   6.23723e-03   2.21438e-04  -2.29285e-01
#    3  p2           2.72396e+01   2.26945e-02   4.09948e-04  -1.41025e-01
# <div id="root_plot_2"
#      style="width: 596px; height: 772px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
#Breit Wigner fit with 5% error
testcanvas12 = ROOT.TCanvas("testcanvas12","Canvas for Tmass data", 600, 800)
dataclone2 = histos["Tmass_data"].Clone()
dataclone2.SetTitle("W Boson Invariant Mass")

dataerrors = {}

#add data uncertainty of 5%
datauncertainty = histos["Tmass_data"].Clone()
datauncertainty.SetTitle("W Boson Transverse Mass")
datauncertainty.SetFillStyle(3154)
datauncertainty.SetFillColor(ROOT.kBlue+2)
datauncertainty.SetLineColor(ROOT.kBlack)
datauncertainty.SetLineWidth(2)
datauncertainty.SetMarkerSize(0)
datauncertainty.SetLineColor(ROOT.kWhite)

for i in range(1, histos["Tmass_data"].GetNbinsX()):
    dataerrors[i] = .025 * histos["Tmass_data"].GetBinContent(i)

    
for i in range(1, histos["Tmass_data"].GetNbinsX()):
    datauncertainty.SetBinError(i, dataerrors[i])
    

#fit the data with Breit Wigner
BreitWigner5 = ROOT.TF1("BreitWigner5", "(([0]*[1]*[2])/(pi))*(((x**2 - [1]**2)**2 +([1]*[2])**2)**-1)", 70.72, 95.40)

BreitWigner5.SetParameter(1, 80)
BreitWigner5.SetParameter(2, 10)
BreitWigner5.SetLineColor(2)
datauncertainty.Fit("BreitWigner5", "", "", 70.72, 95.40)

#make histogram of data
dataclone2.SetMinimum(10)
dataclone2.SetMaximum(5.01e6)
dataclone2.SetFillStyle(3001)
dataclone2.SetFillColor(46)
dataclone2.SetLineColor(1)
dataclone2.GetYaxis().SetTitle("Events/bin")
dataclone2.GetXaxis().SetTitle("M_{T}[GeV]")
dataclone2.GetXaxis().SetTitleOffset(1.2)
dataclone2.GetYaxis().SetLabelSize(0.045)
dataclone2.GetYaxis().SetTitleSize(0.04)
dataclone2.GetYaxis().SetTitleOffset(0.7)

#make legend
legend2=ROOT.TLegend(0.67,0.65,0.90,0.93)
legend2.SetFillStyle(0)
legend2.SetBorderSize(0)
legend2.SetTextAlign(32)
legend2.SetTextFont(42)
legend2.SetTextSize(0.05)
legend2.SetMargin(0.22)
legend2.SetTextAlign(32)
legend2.AddEntry(dataclone2,"Data","l")
legend2.AddEntry(datauncertainty, "Data +/- 2.5% error", "f")
legend2.AddEntry(BreitWigner5, "Breit-Wigner fit", "l")




dataclone2.Draw()
datauncertainty.Draw("e2same")
legend2.Draw()
testcanvas12.Draw()
# Out:
#  FCN=5.58192 FROM MIGRAD    STATUS=CONVERGED     213 CALLS         214 TOTAL
#                      EDM=1.17172e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.69676e+10   6.87123e+08   1.28591e+04  -4.19285e-13
#    2  p1           7.80352e+01   2.93125e-01   2.19808e-04  -1.76451e-04
#    3  p2           2.77020e+01   9.66131e-01   4.90650e-04   3.44465e-04
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: testcanvas12
# <div id="root_plot_11"
#      style="width: 596px; height: 772px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
dataerrors025 = {}
dataerrors01 = {}

dataclone025 = histos["Tmass_data"].Clone()

for i in range(1, histos["Tmass_data"].GetNbinsX()):
    dataerrors025[i] = .025 * histos["Tmass_data"].GetBinContent(i)

    
for i in range(1, histos["Tmass_data"].GetNbinsX()):
    dataclone025.SetBinError(i, dataerrors025[i])

BreitWigner025 = ROOT.TF1("BreitWigner025", "(([0]*[1]*[2])/(pi))*(((x**2 - [1]**2)**2 +([1]*[2])**2)**-1)", 70.72, 95.40)

BreitWigner025.SetParameter(1, 80)
BreitWigner025.SetParameter(2, 10)
BreitWigner025.SetLineColor(2)
dataclone025.Fit("BreitWigner025", "", "", 70.72, 95.40)


dataclone01 = histos["Tmass_data"].Clone()

for i in range(1, histos["Tmass_data"].GetNbinsX()):
    dataerrors01[i] = .01 * histos["Tmass_data"].GetBinContent(i)

    
for i in range(1, histos["Tmass_data"].GetNbinsX()):
    dataclone01.SetBinError(i, dataerrors01[i])

BreitWigner01 = ROOT.TF1("BreitWigner01", "(([0]*[1]*[2])/(pi))*(((x**2 - [1]**2)**2 +([1]*[2])**2)**-1)", 70.72, 95.40)

BreitWigner01.SetParameter(1, 80)
BreitWigner01.SetParameter(2, 10)
BreitWigner01.SetLineColor(2)
dataclone01.Fit("BreitWigner01", "", "", 70.72, 95.40)
# Out:
#  FCN=5.58192 FROM MIGRAD    STATUS=CONVERGED     213 CALLS         214 TOTAL
#                      EDM=1.17172e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.69676e+10   6.87123e+08   1.28591e+04  -4.19285e-13
#    2  p1           7.80352e+01   2.93125e-01   2.19808e-04  -1.76451e-04
#    3  p2           2.77020e+01   9.66131e-01   4.90650e-04   3.44465e-04
#  FCN=34.887 FROM MIGRAD    STATUS=CONVERGED     167 CALLS         168 TOTAL
#                      EDM=1.01771e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.69674e+10   2.74834e+08   1.28591e+04   2.74437e-12
#    2  p1           7.80353e+01   1.17244e-01   2.05389e-04   1.55703e-02
# ...

# %%
#chi^2 for data vs mc
#for question #2

chisquared = 0
for i in range(6, histos["Tmass_data"].GetNbinsX()):
    chisquared += ((MCforchisquared.GetBinContent(i) - histos["Tmass_data"].GetBinContent(i))**2) \
    /((MCforchisquared.GetBinContent(i)))


chisquared5 = 0
for i in range(6, histos["Tmass_data"].GetNbinsX()):
    chisquared5 += ((MCforchisquared.GetBinContent(i) - histos["Tmass_data"].GetBinContent(i))**2) \
    /((.05*MCforchisquared.GetBinContent(i))**2)
    

chisquared25 = 0
for i in range(6, histos["Tmass_data"].GetNbinsX()):
    chisquared25 += ((MCforchisquared.GetBinContent(i) - histos["Tmass_data"].GetBinContent(i))**2) \
    /((.025*MCforchisquared.GetBinContent(i))**2)
    
    
chisquared1 = 0
for i in range(6, histos["Tmass_data"].GetNbinsX()):
    chisquared1 += ((MCforchisquared.GetBinContent(i) - histos["Tmass_data"].GetBinContent(i))**2) \
    /((.01*MCforchisquared.GetBinContent(i))**2)


chisquared005 = 0
for i in range(6, histos["Tmass_data"].GetNbinsX()):
    chisquared005 += ((MCforchisquared.GetBinContent(i) - histos["Tmass_data"].GetBinContent(i))**2) \
    /((.005*MCforchisquared.GetBinContent(i))**2)
    
    
chisquared0025 = 0
for i in range(6, histos["Tmass_data"].GetNbinsX()):
    chisquared0025 += ((MCforchisquared.GetBinContent(i) - histos["Tmass_data"].GetBinContent(i))**2) \
    /((.0025*MCforchisquared.GetBinContent(i))**2)
    
    
chisquared001 = 0
for i in range(6, histos["Tmass_data"].GetNbinsX()):
    chisquared001 += ((MCforchisquared.GetBinContent(i) - histos["Tmass_data"].GetBinContent(i))**2) \
    /((.001*MCforchisquared.GetBinContent(i))**2)
    
    
    
#bins for NDF    
fitbins = 7
nbins = 0
for i in range(6, histos["Tmass_data"].GetNbinsX()):
    nbins += 1
    


    
#Print important values

#data vs MC
print("-------------------------")
print("--Values for data vs MC--")
print("-------------------------")
print("                           ")
print("------------------------------------")
print("Values with sqrt(bin content) error:")
print("chi^2: ", chisquared)
print("NDF: ", nbins)
print("Prob.: ", TMath.Prob(chisquared, nbins))
#data vs MC w/5% error
print("------------------------------------")
print("Values with 5% bin error imposed:")
print("chi^2: ", chisquared5)
print("NDF: ", nbins)
print("Prob.: ", TMath.Prob(chisquared5, nbins))

#data vs MC w/2.5% error
print("------------------------------------")
print("Values with 2.5% bin error imposed:")
print("chi^2: ", chisquared25)
print("NDF: ", nbins)
print("Prob.: ", TMath.Prob(chisquared25, nbins))

#data vs MC w/1% error
print("------------------------------------")
print("Values with 1% bin error imposed:")
print("chi^2: ", chisquared1)
print("NDF: ", nbins)
print("Prob.: ", TMath.Prob(chisquared1, nbins))
print("------------------------------------")
# Out:
# -------------------------
# --Values for data vs MC--
# -------------------------
#
# ------------------------------------
# Values with sqrt(bin content) error:
# chi^2:  18182.405631205867
# NDF:  34
# Prob.:  0.0
# ------------------------------------
# Values with 5% bin error imposed:
# chi^2:  29.063822623312632
# NDF:  34
# Prob.:  0.7082657349042847
# ------------------------------------
# Values with 2.5% bin error imposed:
# chi^2:  116.25529049325053
# NDF:  34
# Prob.:  6.326085038657812e-11
# ------------------------------------
# Values with 1% bin error imposed:
# chi^2:  726.5955655828158
# NDF:  34
# Prob.:  7.671238479977291e-131
# ------------------------------------

# %%
print("---------------------------")
print("--Breit-Wigner fit values--")
print("---------------------------")
print("                           ")
print("----------------------------------")
print("Data w/ sqrt(events) error:")
print("chi^2: ", BreitWigner.GetChisquare())
print("NDF: ", fitbins)
print("Prob.: ", TMath.Prob(BreitWigner.GetChisquare(), fitbins))
print("Mean: 7.80731e+01 +/-6.23726e-03")
print("Width: 2.72396e+01 +/-2.26947e-02")
print("----------------------------------")
print("Data w/ 5% data error:")
print("chi^2: ", BreitWigner5.GetChisquare())
print("NDF: ", fitbins)
print("Prob.: ", TMath.Prob(BreitWigner5.GetChisquare(), fitbins))
print("Mean: 7.80352e+01 +/-5.86219e-01")
print("Width: 2.77019e+01 +/-1.93213e+00")
print("----------------------------------")
print("Data w/ 2.5% data error:")
print("chi^2: ", BreitWigner025.GetChisquare())
print("NDF: ", fitbins)
print("Prob.: ", TMath.Prob(BreitWigner025.GetChisquare(), fitbins))
print("Mean: 7.80352e+01 +/-2.93125e-01")
print("Width: 2.77020e+01 +/-9.66131e-01")
print("----------------------------------")
print("Data w/ 1% data error:")
print("chi^2: ", BreitWigner01.GetChisquare())
print("NDF: ", fitbins)
print("Prob.: ", TMath.Prob(BreitWigner01.GetChisquare(), fitbins))
print("Mean: 7.80353e+01 +/-1.17244e-01")
print("Width: 2.77017e+01 +/-3.86434e-01")
print("----------------------------------")
print(" ")
print("------------------------------")
print("--Particle Data Group values--")
print("------------------------------")
print("                           ")
print("Mean: 80.379 +/-.012GeV")
print("Width: 2.085 +/-.042GeV")
# Out:
# ---------------------------
# --Breit-Wigner fit values--
# ---------------------------
#
# ----------------------------------
# Data w/ sqrt(events) error:
# chi^2:  10922.936824885599
# NDF:  7
# Prob.:  0.0
# Mean: 7.80731e+01 +/-6.23726e-03
# Width: 2.72396e+01 +/-2.26947e-02
# ----------------------------------
# Data w/ 5% data error:
# chi^2:  1.3954799637357402
# NDF:  7
# Prob.:  0.9857093065169165
# Mean: 7.80352e+01 +/-5.86219e-01
# Width: 2.77019e+01 +/-1.93213e+00
# ----------------------------------
# Data w/ 2.5% data error:
# chi^2:  5.581919850666322
# NDF:  7
# Prob.:  0.5893220585887826
# Mean: 7.80352e+01 +/-2.93125e-01
# Width: 2.77020e+01 +/-9.66131e-01
# ----------------------------------
# Data w/ 1% data error:
# chi^2:  34.88699953898714
# NDF:  7
# Prob.:  1.174479731403019e-05
# Mean: 7.80353e+01 +/-1.17244e-01
# Width: 2.77017e+01 +/-3.86434e-01
# ----------------------------------
#
# ------------------------------
# --Particle Data Group values--
# ...

# %%
#sig and sig+bkg for ratio


ratio = ROOT.TH1F("sig/bkg","Tight Lepton Cut",40,39,180)

ratio.Add(singletop)
ratio.Add(ttbar)
ratio.Add(Diboson)
ratio.Add(Zjets)
    

    
sigplusbkg = singletop.Clone()
sigplusbkg.Add(ttbar)
sigplusbkg.Add(Diboson)
sigplusbkg.Add(Zjets)
sigplusbkg.Add(Wjets)

ratio.Divide(sigplusbkg)
# Out:
# True

# %%
#compare MC signal vs background for lepistight analysis



testcanvas13 = ROOT.TCanvas("testcanvas13","Canvas for Tmass data", 800, 600)



#ratio.SetMaximum(40)
ratio.SetFillStyle(3001)
ratio.SetFillColor(46)
ratio.SetLineColor(1)
ratio.SetLineWidth(1)
ratio.GetYaxis().SetTitle("Bkg  /  Sig+Bkg")
ratio.GetXaxis().SetTitle("M_{T}[GeV]")
ratio.GetXaxis().SetTitleOffset(1.3)
ratio.GetXaxis().SetTitleSize(0.045)
ratio.GetXaxis().SetLabelSize(0.035)
ratio.GetYaxis().SetLabelSize(0.035)
ratio.GetYaxis().SetTitleSize(0.045)
ratio.GetYaxis().SetTitleOffset(1.2)



ratio.Draw("hist")
testcanvas13.Draw()
# Out:
# <div id="root_plot_5"
#      style="width: 796px; height: 572px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
#compare total number of events for bkg to sig+bkg
totalevents = ROOT.TH1F("totalevents","Tight Lepton Cut",40,39,180)
totalevents.Add(singletop)
totalevents.Add(ttbar)
totalevents.Add(Diboson)
totalevents.Add(Zjets)
totalevents.Add(Wjets)



totalbkgevents = ROOT.TH1F("totalbkgevents","Tight Lepton Cut",40,39,180)
totalbkgevents.Add(singletop)
totalbkgevents.Add(ttbar)
totalbkgevents.Add(Diboson)
totalbkgevents.Add(Zjets)


ntotalevents = 0
ntotalbkgevents = 0
ntotaleventsdata = 0
for i in range(1, totalevents.GetNbinsX()):
    ntotalevents += totalevents.GetBinContent(i)
    
for i in range(1, totalbkgevents.GetNbinsX()):
    ntotalbkgevents += totalbkgevents.GetBinContent(i)
    
for i in range(1, histos["Tmass_data"].GetNbinsX()):
    ntotaleventsdata += histos["Tmass_data"].GetBinContent(i)

    
    
    
print("total number of bkg events:")
print(ntotalbkgevents)
print("total number of sig+bkg events:")
print(ntotalevents)
print("ratio of bkg / sig+bkg for tight cut is: ")
print(ntotalbkgevents/ntotalevents)
print("total number of data events:")
print(ntotaleventsdata)
# Out:
# total number of bkg events:
# 1365703.7705078125
# total number of sig+bkg events:
# 28828587.46875
# ratio of bkg / sig+bkg for tight cut is:
# 0.047373246156726424
# total number of data events:
# 29402760.0
# Warning in <TFile::Append>: Replacing existing TH1: totalevents (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: totalbkgevents (Potential memory leak).
